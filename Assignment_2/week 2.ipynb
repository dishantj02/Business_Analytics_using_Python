# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
ps = pd.read_excel('/content/gdrive/MyDrive/Colab Notebooks/Task_Data.xlsx')
ps.head(10)
# Out:
# Mounted at /content/gdrive
#    ID   Team Country     NameF      NameL  Weight Height        DOB  \
# 0   1  Women  Canada    Meghan     Agosta   148.0    5'7 1987-02-12
# 1   2  Women  Canada   Rebecca   Johnston   148.0    5'9 1989-09-24
# 2   3  Women  Canada     Laura     Stacey   156.0   5'10 1994-05-05
# 3   4  Women  Canada  Jennifer  Wakefield   172.0   5'10 1989-06-15
# 4   5  Women  Canada   Jillian   Saulnier   144.0    5'5 1992-03-07
# 5   6  Women  Canada   Mélodie     Daoust   159.0    5'6 1992-01-07
# 6   7  Women  Canada    Bailey       Bram   150.0    5'8 1990-09-05
# 7   8  Women  Canada   Brianne     Jenner   156.0    5'9 1991-05-04
# 8   9  Women  Canada     Sarah      Nurse   140.0    5'8 1995-01-04
# 9  10  Women  Canada     Haley      Irwin   170.0    5'7 1988-06-06
#
#       Hometown  Prov      Pos  Age  HeightFt  HtIn  BMI
# 0      Ruthven  Ont.  Forward   35  5.583333    67   23
# 1      Sudbury  Ont.  Forward   32  5.750000    69   22
# ...

# %%
ps.dropna(axis=0,subset=['Weight'],inplace=True)
ps.fillna({ 'DOB':np.nan},inplace=True)
ps
# Out:
#     ID   Team Country     NameF       NameL  Weight Height        DOB  \
# 0    1  Women  Canada    Meghan      Agosta   148.0    5'7 1987-02-12
# 1    2  Women  Canada   Rebecca    Johnston   148.0    5'9 1989-09-24
# 2    3  Women  Canada     Laura      Stacey   156.0   5'10 1994-05-05
# 3    4  Women  Canada  Jennifer   Wakefield   172.0   5'10 1989-06-15
# 4    5  Women  Canada   Jillian    Saulnier   144.0    5'5 1992-03-07
# ..  ..    ...     ...       ...         ...     ...    ...        ...
# 91  92    Men     USA      Ryan        Stoa   210.0    6'3 1987-04-13
# 92  93    Men     USA      Troy       Terry   179.0    6'0 1997-09-10
# 93  94    Men     USA      Noah       Welch   215.0    6'4 1982-08-26
# 94  95    Men     USA     James  Wisniewski   205.0    6'0 1984-02-21
# 95  96    Men     USA      Ryan    Zapolski   203.0    6'0 1986-11-11
#
#            Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# 0           Ruthven   Ont.  Forward   35  5.583333    67   23
# ...

# %%
grp=ps.groupby('Pos')
grp.head()
# Out:
#     ID   Team Country      NameF      NameL  Weight Height        DOB  \
# 0    1  Women  Canada     Meghan     Agosta   148.0    5'7 1987-02-12
# 1    2  Women  Canada    Rebecca   Johnston   148.0    5'9 1989-09-24
# 2    3  Women  Canada      Laura     Stacey   156.0   5'10 1994-05-05
# 3    4  Women  Canada   Jennifer  Wakefield   172.0   5'10 1989-06-15
# 4    5  Women  Canada    Jillian   Saulnier   144.0    5'5 1992-03-07
# 14  15  Women  Canada   Jocelyne   Larocque   139.0    5'6 1988-05-19
# 15  16  Women  Canada   Brigette  Lacquette   180.0    5'6 1992-10-11
# 16  17  Women  Canada   Lauriane    Rougeau   167.0    5'8 1990-04-12
# 17  18  Women  Canada      Laura    Fortino   137.0    5'4 1991-01-30
# 18  19  Women  Canada    Meaghan  Mikkelson   139.0    5'9 1985-01-04
# 20  21  Women  Canada    Shannon   Szabados   146.0    5'8 1986-08-06
# 21  22  Women  Canada  Geneviève    Lacasse   136.0    5'8 1989-05-05
# ...

# %%
ps[ps['Team'] == 'Men']['HtIn'].median()
# Out:
# 72.0

# %%
ps[ps['Team'] == 'Women']['Weight'].mean()
# Out:
# 151.38095238095238

# %%
pd.pivot_table(ps,index=["Country","BMI"],aggfunc=[np.mean,np.median])
# Out:
#                   mean                                             median  \
#                    Age  HeightFt       HtIn         ID      Weight    Age
# Country BMI
# Canada  20   26.000000  5.583333  67.000000  12.000000  130.000000   26.0
#         21   32.333333  5.694444  68.333333  16.666667  138.333333   33.0
#         22   32.250000  5.687500  68.250000  10.250000  147.250000   33.0
#         23   31.800000  5.733333  68.800000  16.400000  155.800000   31.0
#         24   30.500000  5.722222  68.666667  20.500000  160.833333   30.0
#         25   33.857143  5.833333  70.000000  27.571429  175.285714   33.0
#         26   33.363636  5.901515  70.818182  30.272727  185.727273   32.0
#         27   34.666667  6.000000  72.000000  31.000000  198.000000   35.0
#         28   67.000000  6.000000  72.000000  35.000000  204.333333   40.0
#         29   33.000000  5.750000  69.000000  25.500000  198.000000   33.0
# ...

# %%
ps1=ps[ps['Team'] == 'Women']
ps2=ps1[ps['Country'] == 'USA']
ps3=ps[ps['Team'] == 'Men']
ps4=ps3[ps['Country'] == 'Canada']
ps2.join(ps4,lsuffix='m',rsuffix='w')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#     IDm  Teamm Countrym    NameFm              NameLm  Weightm Heightm  \
# 48   49  Women      USA     Cayla              Barnes    145.0     5'1
# 49   50  Women      USA     Kacey             Bellamy    145.0     5'7
# 50   51  Women      USA    Hannah              Brandt    150.0     5'6
# 52   53  Women      USA   Kendall               Coyne    123.0     5'2
# 53   54  Women      USA   Brianna              Decker    150.0     5'4
# 55   56  Women      USA      Kali            Flanagan    142.0     5'4
# 56   57  Women      USA    Nicole             Hensley    155.0     5'7
# 57   58  Women      USA     Megan              Keller    160.0    5'11
# ...
